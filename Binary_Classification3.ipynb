# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv(r"C:\Users\Neel Arora\Downloads\personality_datasert.csv")
data
# Out:
#       Time_spent_Alone Stage_fear  Social_event_attendance  Going_outside  \
# 0                  4.0         No                      4.0            6.0
# 1                  9.0        Yes                      0.0            0.0
# 2                  9.0        Yes                      1.0            2.0
# 3                  0.0         No                      6.0            7.0
# 4                  3.0         No                      9.0            4.0
# ...                ...        ...                      ...            ...
# 2895               3.0         No                      7.0            6.0
# 2896               3.0         No                      8.0            3.0
# 2897               4.0        Yes                      1.0            1.0
# 2898              11.0        Yes                      1.0            3.0
# 2899               3.0         No                      6.0            6.0
#
#      Drained_after_socializing  Friends_circle_size  Post_frequency  \
# ...

# %%
plt.figure(figsize=(10, 6))
scatter = plt.scatter(data.Stage_fear, 
                     data.Social_event_attendance,
                     cmap='coolwarm',
                     alpha=0.6)
plt.colorbar(scatter, label='Personality')
plt.xlabel('Stage_fear')
plt.ylabel('Social_event_attendance')
plt.title('Stage_fear vs Social_event_attendance')
plt.show()
# Out:
# C:\Users\Neel Arora\AppData\Local\Temp\ipykernel_18412\286464503.py:2: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = plt.scatter(data.Stage_fear,

# %%
data.shape
# Out:
# (2900, 8)

# %%
x_data = [[stage_fear, Social_event_attendance]]
y_data = data.Personality
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 x_data = [[stage_fear, Social_event_attendance]]
#       2 y_data = data.Personality
#       3 x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3)
#
# NameError: name 'stage_fear' is not defined
